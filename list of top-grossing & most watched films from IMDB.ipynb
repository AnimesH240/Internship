# %% [markdown]
# <a href="https://colab.research.google.com/github/AnimesH240/Python-AIML-RPA-Development/blob/main/list%20of%20top-grossing%20%26%20most%20watched%20films%20from%20IMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Utility tool that identifies a list of top-grossing & most watched films from IMDB.

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
movies = soup.select('td.titleColumn')

list = []

for index in range(0, len(movies)):
	movie_string = movies[index].get_text()
	movie = (' '.join(movie_string.split()).replace('.', ''))
	movie_title = movie[len(str(index))+1:-7]
	place = movie[:len(str(index))-(len(movie))]
	data = {"place": place, "movie_title": movie_title}
	list.append(data)

for movie in list:
	print(movie['place'], '-', movie['movie_title'])
# Out:
# 1 - The Shawshank Redemption
# 2 - The Godfather
# 3 - The Dark Knight
# 4 - The Godfather Part II
# 5 - De 12 gezworenen
# 6 - Schindler's List
# 7 - The Lord of the Rings: The Return of the King
# 8 - Pulp Fiction
# 9 - The Lord of the Rings: The Fellowship of the Ring
# 1 -  The Good, the Bad and the Ugly
# 11 - Forrest Gump
# 12 - Fight Club
# 13 - Inception
# 14 - The Lord of the Rings: The Two Towers
# 15 - Star Wars: Episode V - The Empire Strikes Back
# 16 - The Matrix
# 17 - Goodfellas
# 18 - One Flew Over the Cuckoo's Nest
# 19 - Seven
# 20 - Shichinin no samurai
# 21 - It's a Wonderful Life
# 22 - The Silence of the Lambs
# 23 - Cidade de Deus
# 24 - Saving Private Ryan
# 25 - Het leven is mooi
# 26 - The Green Mile
# 27 - Interstellar
# 28 - De sterrenoorlogen
# 29 - Terminator 2: Judgment Day
# 30 - Terug naar de toekomst
# 31 - Spirited Away
# 32 - Psycho
# 33 - The Pianist
# 34 - Léon
# 35 - Gisaengchung
# 36 - The Lion King
# 37 - Gladiator
# 38 - American History X
# ...
